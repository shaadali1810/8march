# %%
#1
#A probability density function (PDF) is a statistical expression that defines the probability that some outcome will occur.3 It represents a probability distribution in terms of integrals and is used to find the chances that the value of a random variable will occur within a specified range of values.2 PDFs are typically depicted on a graph, with a normal bell curve indicating neutral market risk and a skewed curve at either end indicating greater or lesser risk-reward.3 PDFs are used in the case of continuous random variables, while for discrete random variables, the probability mass function is analogous to the PDF.0 The probability that a continuous random variable takes a value in a given interval is equal to the integral of its PDF over that interval

# %%
#2 type of distrubtion function
#i) discreate probabilty function
#ii) cummalative probabilty fucntion

# %%
#3
import math

# %%
def nompdf(x,mean,sd):
    var = float(sd)**2
    denom = (2*math.pi*var)**.5
    num = math.exp(-(float(x)-float(mean))**2/(2*var))
    return num/denom

# %%
nompdf(7,5,5)
# Out:
# 0.07365402806066466

# %%
#4
#discuss random variable
#every experiment outcome is ninary
# these experiment is perfomed for n trial
#eg tossing a coin 10 times,
#eg2 thrown a dice 15times

# %%
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(10)
size = 1000
sample = np.random.binomial(20,0.4,size)
bin = np.arange(0,20,1)
plt.hist(sample,bins=bin,edgecolor= 'blue')
plt.title('binomial distribution')
plt.show()

# %%
from scipy.stats import poisson
data_poisson = poisson.rvs(mu=3,size = 1000)

# %%
import seaborn as sns

# %%
ax = sns.distplot(data_poisson,bins=30,kde=False,color = 'skyblue',
                 hist_kws={'linewidth':15,'alpha':1})
ax.set(xlabel = 'poisson distribution', ylabel= 'frequency')
# Out:
# /tmp/ipykernel_77/2363225184.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(data_poisson,bins=30,kde=False,color = 'skyblue',
# [Text(0.5, 0, 'poisson distribution'), Text(0, 0.5, 'frequency')]

# %%
#7
#The Binomial distribution and the Poisson distribution are two different probability distributions.01 The Binomial distribution is based on discrete events, while the Poisson distribution is based on continuous events. In a Binomial distribution, there are only two outcomes, while in a Poisson distribution, there are infinite attempts with infinitesimal chance of success.1 The Poisson binomial distribution is the discrete probability distribution of a sum of independent Bernoulli trials that are not necessarily identically distributed. The entropy of a Poisson binomial distribution is bounded above by the entropy of a Binomial distribution with the same number parameter and the same mean. The mean and variance of a Poisson binomial distribution are simply sums of the mean and variance of the n independent Bernoulli distributions.

# %%
#8
np.random.seed(10)
size = 1000
sample = np.random.poisson(5,size)
plt.hist(sample)
plt.show()

# %%
#9The mean and variance are related in the Binomial distribution and the Poisson distribution. The mean of the Binomial distribution is n, while the variance of the Poisson distribution is n(1 – ). Substituting = h, we get the variance as nh(1 – h). As n tends to infinity and h to 0 we get the limit t. Therefore, the variance in unit time is. For example, if the average number of 'page not found' errors on a web server is 36 in a 24-h period, then the probability in a 60-min period that the process is a Poisson process is 1.5.

# %%
#10
#
